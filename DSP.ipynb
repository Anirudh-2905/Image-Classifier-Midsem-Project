# %% [markdown]
# <a href="https://colab.research.google.com/github/Anirudh-2905/Image-Classifier-Midsem-Project/blob/main/DSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/1_3.zip" -d "/content/drive/My Drive/DSP"

# %%
print("ani")
# Out:
# ani
